# %%
# import pandas as pd
# df = pd.read_csv('dataset.csv')

# %%
import numpy as np

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]

a = np.array(x)
b = np.array(y)

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
import matplotlib.pyplot as plt
plt.plot(a,b)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.linear_model import LinearRegression

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
n = np.size(a)
x_mean = np.mean(a)
y_mean = np.mean(b)

m = (np.sum(a * b) - n*(x_mean * y_mean))/(np.sum(a * a) - n*(x_mean * x_mean))
print("m = ",m)
m1 = np.sum(a*b) - n * (x_mean * y_mean)

m2 = np.sum(a*a) - n * (x_mean * x_mean)

print("m1: ", m1)
print("m2: ", m2)

c = y_mean - m * x_mean
print("c: ", c)
# Out:
# m =  2.0
# m1:  20.0
# m2:  10.0
# c:  0.0

# %%
x_giv = [7,8,9,10]
a_giv = np.array(x_given)
# y_pred = m * (x_given) + c
x = a_giv.reshape(-1,1)  #reshaped the array/value of x into new dimensions


regression_mod = LinearRegression()
regression_mod.fit(x,b)
y_predicted = regression_mod.predict(x)
mse = mean_square_error(b,y_predicted)
print(y_predicted)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 8
#       4 x = a_giv.reshape(-1,1)  #reshaped the array/value of x into new dimensions
#       7 regression_mod = LinearRegression()
# ----> 8 regression_mod.fit(x,b)
#       9 y_predicted = regression_mod.predict(x)
#      10 mse = mean_square_error(b,y_predicted)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
# ...

# %%
x_giv = [7, 8, 9, 10, 11]
a2 = np.array(x_giv)

a2
# Out:
# array([ 7,  8,  9, 10, 11])

# %%
import pandas as pd
df=pd.read_csv('bmi.csv')
# print(df)
#print(df.to_string())

data_pandas = pd.DataFrame(df)
#IPython.display allows fine printing of dataframes in Jupyter
display(data_pandas)

#print(df['weight'])
##print(df['height'])
#print(df['bmi'])


d1 = df['weight']
d2 = df['height']
ch = df['bmi']

a1 = d1.to_numpy()
a2 = d1.to_numpy()


###b1 = df.reshape(-1,2)

print(a1)
print(a2)
print(ch)
# Out:
#     SERIAL NO  weight  height  gender    bmi  chance  conclusion
# 0           1    83.0     161     NaN  32.02       1        1.61
# 1           2    94.0     186     NaN  27.17       1        1.86
# 2           3    94.0     188     NaN  26.60       1        1.88
# 3           4    85.0     182     NaN  25.66       1        1.82
# 4           5    68.0     163  female  25.59       1        1.63
# 5           6    60.0     166  female  21.77       0        1.66
# 6           7    61.0     171    male  20.86       0        1.71
# 7           8   100.0     173  female  33.41       1        1.73
# 8           9    82.0     177     NaN  26.17       1        1.77
# 9          10    80.0     178     NaN  25.25       1        1.78
# 10         11    65.0     176  female  20.98       0        1.76
# 11         12    52.0     163  female  19.57       0        1.63
# 12         13    60.0     171  female  20.52       0        1.71
# ...

# %%
x8 = np.concatenate(d1, d2)
a = x8.reshape(-1, 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 x8 = np.concatenate(d1, d2)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# TypeError: 'Series' object cannot be interpreted as an integer
